# %% [markdown]
# # Exploratory Data Analysis with Python on Online Retail Data Set

# %% [markdown]
# ## Project Objectives
# 1. Describe data to answer key questions to uncover insights
# 2. Gain valuable insights that will help improve online retail performance
# 3. Provide analytic insights and data-driven recommendations

# %% [markdown]
# ## Dataset
#
# The dataset contains the following columns:
#
# - InvoiceNo: Invoice number of the transaction
# - StockCode: Unique code of the product
# - Description: Description of the product
# - Quantity: Quantity of the product in the transaction
# - InvoiceDate: Date and time of the transaction
# - UnitPrice: Unit price of the product
# - CustomerID: Unique identifier of the customer
# - Country: Country where the transaction occurred

# %% [markdown]
# ## Tasks
#
# You may explore this dataset in any way you would like - however if you'd like some help getting started, here are a few ideas:
#
# 1. Load the dataset into a Pandas DataFrame and display the first few rows to get an overview of the data.
# 2. Perform data cleaning by handling missing values, if any, and removing any redundant or unnecessary columns.
# 3. Explore the basic statistics of the dataset, including measures of central tendency and dispersion.
# 4. Perform data visualization to gain insights into the dataset. Generate appropriate plots, such as histograms, scatter plots, or bar plots, to visualize different aspects of the data.
# 5. Analyze the sales trends over time. Identify the busiest months and days of the week in terms of sales.
# 6. Explore the top-selling products and countries based on the quantity sold.
# 7. Identify any outliers or anomalies in the dataset and discuss their potential impact on the analysis.
# 8. Draw conclusions and summarize your findings from the exploratory data analysis.

# %% [markdown]
# # Task 1:  Load the dataset into a Pandas DataFrame and display the first few rows to get an overview of the data.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = data = pd.read_csv("Online Retail.csv")

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# # Task 2 :  Perform data cleaning by handling missing values, if any, and removing any redundant or unnecessary columns.

# %%
# Display the first few rows to understand the structure
print(df.head())

# Check the columns and their data types
print(df.info())

# Summary statistics of numerical columns
print(df.describe())

# Check for missing values
print(df.isnull().sum())
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
# ...

# %%
# Handle missing values (if any)
df.dropna(inplace=True)  # Example: Dropping rows with missing values

# Convert date columns to datetime format
df['InvoiceDate'] = pd.to_datetime(data['InvoiceDate'])

# Remove duplicates if present
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# # Task 3:  Exploratory Data Analysis (EDA)

# %% [markdown]
# # Univariate Analysis
#
# Univariate analysis is a statistical method used to analyze a single variable in isolation. In this method, we examine and summarize the characteristics and properties of that specific variable without considering relationships with other variables. It's about understanding the distribution, frequency, and behavior of a single variable.
#
# ## Techniques used in Univariate Analysis:
# Central Tendency Measures: Understanding the central or average value of the variable. This includes mean, median, and mode.
#
# Dispersion Measures: Assessing the spread or variability of the variable. Measures like range, variance, standard deviation, and quartiles help understand the data's variability.
#
# Frequency Distribution: Displaying how often each value in the variable occurs. Histograms, frequency tables, and density plots are used to represent this.
#
# Summary Statistics: Providing a summary of the variable's characteristics using statistical methods, such as skewness, kurtosis, and percentiles.
#
# Visualization Techniques: Plotting graphs or charts (like histograms, box plots, kernel density estimation plots) to visualize the distribution and characteristics of the variable.
#
# Purpose of Univariate Analysis:
# Data Understanding: It helps in understanding the basic properties and nature of the variable being analyzed.
# Data Cleaning: Identifying anomalies or outliers within the variable.
# Feature Selection: Selecting relevant variables for further analysis or modeling.
# Initial Insights: Providing initial insights into the dataset before performing more complex analyses.
# Univariate analysis forms the foundational step in exploratory data analysis, allowing for a comprehensive understanding of individual variables and their distributions.

# %%
# Visualize the distribution of numerical variables
sns.histplot(data['Quantity'], bins=20, kde=True)
plt.title('Distribution of Quantity')
plt.show()

# Visualize categorical variables
sns.countplot(x='Country', data=data)
plt.title('Count of Orders by Country')
plt.xticks(rotation=90)
plt.show()

# %%
#Bivariate Analysis

# %%
# Relationship between two numerical variables
sns.scatterplot(x='Quantity', y='UnitPrice', data=data)
plt.title('Quantity vs UnitPrice')
plt.show()

# Relationship between numerical and categorical variables
sns.boxplot(x='Country', y='Quantity', data=data)
plt.title('Quantity by Country')
plt.xticks(rotation=90)
plt.show()

# %%
#Multivariate Analysis

# %%
# Assuming you want to calculate the correlation between numerical columns
numerical_data = data.select_dtypes(include='number')
correlation_matrix = numerical_data.corr()

plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# # Task 4: Perform data visualization to gain insights into the dataset. Generate appropriate plots, such as histograms, scatter plots, or bar plots, to visualize different aspects of the data.

# %%
#Time Series Plot - Monthly Sales Trend

# %%
# Assuming 'InvoiceDate' is the datetime column
data['InvoiceMonth'] = data['InvoiceDate'].dt.to_period('M')
monthly_sales = data.groupby('InvoiceMonth')['Quantity'].sum()

plt.figure(figsize=(10, 6))
monthly_sales.plot(marker='o')
plt.title('Monthly Sales Trend')
plt.xlabel('Month')
plt.ylabel('Total Sales Quantity')
plt.grid(True)
plt.show()

# %%
#Histogram - Distribution of Quantity Purchased

# %%
plt.figure(figsize=(8, 5))
sns.histplot(data['Quantity'], bins=30, kde=True)
plt.title('Distribution of Quantity Purchased')
plt.xlabel('Quantity')
plt.ylabel('Frequency')
plt.show()

# %%
#Box Plot - Quantity by Country

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Country', y='Quantity', data=data)
plt.title('Quantity by Country')
plt.xlabel('Country')
plt.ylabel('Quantity')
plt.xticks(rotation=90)
plt.show()

# %%
#Scatter Plot - Unit Price vs Quantity

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='UnitPrice', y='Quantity', data=data)
plt.title('Unit Price vs Quantity')
plt.xlabel('Unit Price')
plt.ylabel('Quantity')
plt.show()

# %%
#Correlation Matrix Heatmap

# %%
numerical_data = data.select_dtypes(include='number')
correlation_matrix = numerical_data.corr()

plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# # Task 5: Analyze the sales trends over time. Identify the busiest months and days of the week in terms of sales.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_csv('Online Retail.csv')  

# Convert 'InvoiceDate' column to datetime
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])

# Extract month and day of the week from the 'InvoiceDate'
df['Month'] = df['InvoiceDate'].dt.month
df['Day_of_Week'] = df['InvoiceDate'].dt.day_name()

# Group by month and day of the week to get sales data
monthly_sales = df.groupby('Month')['Quantity'].sum()
weekly_sales = df.groupby('Day_of_Week')['Quantity'].sum()

# Plotting monthly sales trend
plt.figure(figsize=(10, 6))
monthly_sales.plot(marker='o')
plt.title('Monthly Sales Trend')
plt.xlabel('Month')
plt.ylabel('Total Sales Quantity')
plt.grid(True)
plt.xticks(range(1, 13))  # Assuming data spans a year
plt.show()

# Plotting sales by day of the week
plt.figure(figsize=(8, 5))
sns.barplot(x=weekly_sales.index, y=weekly_sales.values, order=[
            'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])
plt.title('Total Sales by Day of the Week')
plt.xlabel('Day of the Week')
plt.ylabel('Total Sales Quantity')
plt.show()

# Identifying the busiest month
busiest_month = monthly_sales.idxmax()
print(f"The busiest month in terms of sales is {busiest_month}")

# Identifying the busiest day of the week
busiest_day = weekly_sales.idxmax()
print(f"The busiest day of the week in terms of sales is {busiest_day}")
# Out:
# The busiest month in terms of sales is 11
# The busiest day of the week in terms of sales is Thursday

# %% [markdown]
# # Task 6:  Explore the top-selling products and countries based on the quantity sold.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_csv('Online Retail.csv')  

# Group data by Product ID to find top-selling products
top_products = df.groupby('StockCode')['Quantity'].sum().sort_values(ascending=False).head(10)

# Group data by Country to find top-selling countries
top_countries = df.groupby('Country')['Quantity'].sum().sort_values(ascending=False).head(10)

# Plotting top-selling products
plt.figure(figsize=(10, 6))
top_products.plot(kind='bar', color='skyblue')
plt.title('Top Selling Products')
plt.xlabel('Product ID')
plt.ylabel('Total Quantity Sold')
plt.xticks(rotation=45)
plt.show()

# Plotting top-selling countries
plt.figure(figsize=(10, 6))
top_countries.plot(kind='bar', color='salmon')
plt.title('Top Selling Countries')
plt.xlabel('Country')
plt.ylabel('Total Quantity Sold')
plt.xticks(rotation=45)
plt.show()

# Displaying top products and countries
print("Top Selling Products:")
print(top_products)

print("\nTop Selling Countries:")
print(top_countries)
# Out:
# Top Selling Products:
# StockCode
# 22197     56450
# 84077     53847
# 85099B    47363
# 85123A    38830
# 84879     36221
# 21212     36039
# 23084     30646
# 22492     26437
# 22616     26315
# 21977     24753
# Name: Quantity, dtype: int64
#
# Top Selling Countries:
# Country
# United Kingdom    4263829
# Netherlands        200128
# EIRE               142637
# Germany            117448
# France             110480
# Australia           83653
# Sweden              35637
# Switzerland         30325
# Spain               26824
# Japan               25218
# Name: Quantity, dtype: int64

# %% [markdown]
# # Task 7: Identify any outliers or anomalies in the dataset and discuss their potential impact on the analysis.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv('Online Retail.csv')  

# Plot boxplots to visualize outliers in Quantity and UnitPrice
plt.figure(figsize=(10, 6))
sns.boxplot(data['Quantity'])
plt.title('Boxplot of Quantity')
plt.show()

plt.figure(figsize=(10, 6))
sns.boxplot(data['UnitPrice'])
plt.title('Boxplot of UnitPrice')
plt.show()

# %% [markdown]
# # Task 8:  Draw conclusions and summarize your findings from the exploratory data analysis.

# %% [markdown]
# In an exploratory data analysis (EDA) of the online retail dataset, several key findings and insights emerged:
#
# ### Sales Trends:
# - **Monthly Sales Trend:** Identified fluctuations in sales across months, indicating potential seasonal trends or variations.
# - **Busiest Months:** Found peaks in sales during specific months, suggesting potential seasonal influences on purchasing behavior.
#
# ### Product Insights:
# - **Top-Selling Products:** Identified the top-selling products based on quantity sold, providing insight into customer preferences or popular items.
# - **Outliers in Quantity:** Detected potential outliers in quantities sold, which might impact analyses related to product popularity or customer buying habits.
#
# ### Geographic Trends:
# - **Top-Selling Countries:** Recognized the countries with the highest sales volumes, highlighting potential areas of market strength or customer base concentration.
#
# ### Anomalies and Outliers:
# - **Identification of Outliers:** Found outliers in quantity and unit price, which could potentially skew statistical measures or trends.
# - **Impact on Analysis:** Acknowledged that outliers might distort statistical calculations, influencing the interpretation of trends or patterns.
#
# ### Potential Actions:
# - **Handling Outliers:** Recognized the need to handle outliers carefully, considering their potential impact on analysis and decision-making.
# - **Further Investigation:** Highlighted the need for deeper analysis to understand the underlying reasons behind sales spikes, outliers, or trends observed.
#
# ### Recommendations:
# - **Data Cleaning:** Suggested a thorough data cleaning process to ensure data quality and reliability.
# - **Seasonal Marketing Strategies:** Suggested leveraging seasonal trends for targeted marketing or inventory planning.
# - **Geographic Focus:** Encouraged focusing efforts on regions with high sales potential based on the analysis.
#
# In summary, the EDA provided valuable insights into sales trends, product performance, geographical variations, and potential anomalies within the dataset. Addressing outliers and leveraging identified patterns can assist in making informed business decisions, refining marketing strategies, and optimizing operations within the online retail space.

# %% [markdown]
# # The End
